# %% [markdown]
# # Advanced Python: Applied AI/ML Techniques
#
# ### Day 3: NumPy / PyTorch features and Overview on Pandas
# - ```numpy``` / ```pytorch```: Odds and Ends
#    - Indexing, Slicing/Dicing techniques
#    - Transformation and Filtering operations
#    - Demo: implementing few activation functions
#    - Demo: Image manipulation using numpy operations
# - Introduction to Pandas
# - Pandas `Series` and `DataFrame`
# - Data cleaning: handling missing data, duplicates and outliers
# - Reading CSV and Excel spreadsheets
# - Data manipulation techniques

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# ### Reduction functions

# %%
a = torch.tensor([14, 78, 12, 13, 89, 15, 62, 67, 19, 27, 33, 30, 16], dtype=torch.float32)
print("Sum: ", a.sum())
print("Product: ", a.prod())
print("Minimum: ", a.min())
print("Maximum: ", a.max())
print("ArgMin: ", a.argmin())
print("ArgMax: ", a.argmax())   
print("Mean: ", a.mean())
print("Standard Deviation: ", a.std())
print("Variance: ", a.var())
print("Median: ", a.median())
print("All: ", a.all())
print("Any: ", a.any())

# %% [markdown]
# ### Transformation functions

# %%
print("Sine: ", torch.sin(a))
print("Cosine: ", torch.cos(a))
print("Tangent: ", torch.tan(a))
print("Exponential: ", torch.exp(a))
print("Logarithm: ", torch.log(a))
print("Square Root: ", torch.sqrt(a))
print("Power: ", torch.pow(a, 2))
print("Absolute Value: ", torch.abs(a))
print("Round: ", torch.round(a))
print("Floor: ", torch.floor(a))
print("Ceil: ", torch.ceil(a))
print("Sign: ", torch.sign(a))
print("Reciprocal: ", torch.reciprocal(a))

print("Clamping: ", torch.clamp(a, min=20, max=80))
print("Normalization: ", (a - a.mean()) / a.std())

print("Softmax: ", torch.softmax(a, dim=0))
print("Sigmoid: ", torch.sigmoid(a))
print("Tanh: ", torch.tanh(a))
print("ReLU: ", torch.relu(a))

print("Unique: ", torch.unique(a))
print("Top-k: ", torch.topk(a, k=3))
print("Sorting: ", torch.sort(a))
print("Cumulative Sum: ", torch.cumsum(a, dim=0))
print("Cumulative Product: ", torch.cumprod(a, dim=0))
print("Difference: ", torch.diff(a))
print("Non-zero: ", torch.nonzero(a))

# %% [markdown]
# #### Mutation operations on tensors

# %%
a = torch.tensor([10, 20, 30, 40, 50, 60])
a

# %%
a[0] = 100
print(a)

# %%
a[:3] = 0
print(a)

# %%
a = torch.arange(100).reshape(10, 10)
print(a)

# %%
a[3:7, 3:7] = 0
print(a)

# %%
a[::2] = 0
print(a)

# %%
torch.random.manual_seed(42)    
a = torch.randint(10, 100, (15,))
a

# %%
b = a > 50
print(b, b.dtype)

# %%
x = torch.arange(9).reshape(3, 3)
y  = torch.arange(1, 4).unsqueeze(dim=1)
print(x, y, sep="\n")

y1 = torch.arange(1, 4)
print(y1)

z = x @ y # x.dot(y), torch.dot(x, y)
print(z)

print(x @ y1)

# %%
# Element-wise (broadcast operations)
print(x)
print(x + 1)
print(x * 2)
print(x ** 2)

# %%
t1 = torch.tensor([10, 20, 30])
t2 = torch.tensor([11, 22, 33], device="mps")

t3 = t1 + t2
print(t3)

# %%
t1 = torch.tensor([10, 20, 30], device="mps")
t2 = torch.tensor([11, 22, 33], device="mps")

t3 = t1 + t2
print(t3)

# %%
a = torch.tensor([2, 5, 3])
b = torch.tensor([4, 5, 6]).reshape(3, 1)
print(a)
print(b)
a + b

# %%
z = torch.add(x, y)
z

# %%
a = torch.tensor([10, 20])
print(a.add(5))  # a + 5
print(a.mul(3))  # a * 3
print(a)

# %%
a = torch.tensor([10, 20])
print(a.add_(5))  # a += 5
print(a)

b = a.add_(5)   # b = a += 5
print(a, b)

# %%
a = torch.tensor([10, 20])
a += 5
print(a)

# %%
a = torch.tensor([10, 20])
b = a += 5 # This wont work - Python syntax does not allow this

# %%
x = torch.arange(10)
y = 2

print(x)
z = x.mul_(y)  # all methods ending with _ performs in-place operation
print(x, z, sep="\n")

# %%
z = x - y
print(z)
z = torch.sub(x, y)
print(z)

# %%
z = torch.mul(x, y)
print(z)

# %%
x = torch.arange(12).reshape(3, 4)
x[1, 1]

# %%
x[1, 1].item()

# %%
x = torch.arange(10)
y = x.view(5, 2)
y

# %%
x = torch.rand(4, 4)
print(x.shape)
y = x.view(-1, 8)
print(y.shape)

# %% [markdown]
# ##### Slicing / Dicing with numpy arrays / pytorch tensors

# %%
a = torch.arange(25)
print(a)
print(a[:5], a[-5:], a[3:7])
print(a[::2])

# %%
a = torch.arange(10)
print(a)
print(a[:3])

a[:3] = 10
print(a)

# %%
a = torch.arange(25).reshape(5, 5)
print(a)
a[1, 1]

# %%
a = torch.arange(25).reshape(5, 5)
print(a)
a[:3, 1]

# %%
a[:3, :3]

# %%
a[:, ::2]

# %%
a[::2, :]

# %%
print(a)
print(a[1:4, 1:4])

# %% [markdown]
# ##### Interesting slicing use-case

# %%
a = torch.tensor([1, 2, 3, 4, 5, 6])
print(a, a.shape)

print(a.reshape(2, 3))
print(a.reshape(1, 6))
b = a.reshape(1, -1)
print(b, b.shape)

# %%
a = torch.arange(24)
a

# %%
a.reshape(4, -1)  # Same as a.reshape(4, 6)

# %%
a.reshape(-1, 4)

# %%
a.reshape(2, -1, 4)

# %%
a = torch.arange(25).reshape(5, 5)
print(a)
a[:3, :3]

# %%
a = torch.arange(100).reshape(10, 10)
print(a)
a[:5, :5]

# %%
a = torch.arange(100).reshape(10, 10)
print(a)
a[:5:2, :5:2]

# %%
a = torch.arange(100).reshape(10, 10)
print(a)
a[::2, ::2]

# %%
a = torch.arange(100).reshape(10, 10)
print(a[:, 3])
print(a[3])

# %%
a = torch.arange(100).reshape(10, 10)
#b = a[:, 3].reshape(10, 1)
b = a[:, 3].reshape(-1, 1)
print(b, b.shape)

# %%
a = torch.arange(100).reshape(10, 10)
b = a[:, 3:5]
print(b, b.shape)

# %%
a = torch.arange(100).reshape(10, 10)
print(a)
a[:, 3] = 0
print(a)

# %%
a = torch.arange(25).reshape(5, 5)
b = a + 10

print(a, b, sep="\n\n")

# %%
a = torch.arange(25).reshape(5, 5)

print(a)
print()

a += 10

print(a)

# %%
a = torch.tensor([10, 20, 30, 40])
b = torch.tensor([11, 22, 33, 44])

print(a + b)

# %%
a = torch.tensor([10, 20, 30, 40, 50, 60])
print(a + 1)
print(a - 1)
print(a * 2)
print(a ** 2)

# %%
a = torch.tensor([10, 20, 30, 40])
b = torch.tensor([11, 22, 33, 44])
print(a.shape, b.shape)

c = a + b  # + performs element-wise addition, not "concatenation"
print(c)
print(b - a)
print(a * b)

# %%
a = torch.arange(25).reshape(5, 5)
print(a)

# %%
b = torch.arange(5)
b

# %%
print(b.shape)
b = b.reshape(-1, 1)
print(b.shape)
print(b)

# %%
print(a)

# %%
a + b

# %%
a = torch.arange(5)
print(a, a.shape)

b = a.reshape(-1, 1)
print(b, b.shape)

c = a + b
print(c)

# %% [markdown]
# ### Filtering operations

# %%
a = torch.tensor([22, 55, 77, 11, 22, 88])
print(a)

# Subscripting using a list-of-indices
print(a[[3, 0, 2, 4]]) 

# Subscripting using a list-of-booleans
print(a[[True, False, False, True, False, True]])

# %%
np.random.seed(42)
a = np.random.randint(10, 100, 15)
a

# %%
b = a > 50  # Comparison is applied element-wise returning an array of booleans
print(b, b.dtype)

# %%
print(a)
print(a[a > 50]) # Extracts all items that are greater than 50 (a filter operation)

# %%
a[a % 2 == 1]

# %%
print(a)
a[a > 50] = 0
print(a)

# %%
a = [10, 20, 30, 40, 50, 60, 70, 80]
a[:3] = [0] * 3
a

# %%
a = [10, 20, 30, 40, 50, 60, 70, 80, 90]
a[:5:2]

# %%
a = np.arange(25).reshape(5,5)
#b1 = np.full(5, 10)
b1 = np.array([2, 5, 3, 1, 4])
b2 = b1.reshape(-1, 1)

print(a, b1, b2, sep="\n\n")
print("a - b1:", a-b1, sep="\n\n")
print("a - b2:", a-b2, sep="\n\n")

# %%
# To select a subset of items from a numpy array, you can pass a list of indices of choice
# Filter based on list of indices
a = np.array([14, 78, 12, 13, 89, 15, 62, 67, 19, 27, 33, 30, 16])
a[[4, 2, -4, 5]]

# %%
# To select a subset of items from a numpy array, you can pass a list of booleans
# Filter based on criteria
a = np.array([14, 78, 12, 13])
print(a)
a[[True, False, False, True]]

# %%
a = np.array([14, 78, 12, 13, 89, 15, 62, 67, 19, 27, 33, 30, 16])

a < 20

# %%
a = np.array([14, 78, 12, 13, 89, 15, 62, 67, 19, 27, 33, 30, 16])

a[a < 20]

# %%
a = np.array([14, 78, 12, 13, 89, 15, 62, 67, 19, 27, 33, 30, 16])

print(a[a % 2 != 0])

print(a & 1)
print(a[a & 1])
print(a[a & 1 == 0])

# %%
a = torch.tensor([14, 78, 12, 13, 89, 15, 62, 67, 19, 27, 33, 30, 16])

print(a[a % 2 != 0])

print(a & 1)
print(a[a & 1])
print(a[a & 1 == 0])

# %%
x = torch.tensor([14, 78, 12, 13, 89, 15, 62, 67, 19, 27, 33, 30, 16])
y = torch.where(x > 50, x, 0)
y

# %%
a = np.array([1, -2, 3, -4, 5, -6])
print(a)
b = np.where(a > 0, a, 0)
print(b)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ---

# %% [markdown]
# ### Example use-cases: implementing activation functions

# %% [markdown]
# ```ReLU``` (Rectified Linear Unit) is a widely used
# activation function in deep learning that outputs
# the input directly if it is positive and returns
# zero otherwise.
#
# It is defined by the formula:
#
# $$f(x) = max(0, x)$$

# %%
# Implementing ReLU using torch.where
x = torch.arange(-10, 10)
y = x.where(x >= 0, 0)
print(y)

# Another way to implement ReLU using torch.max
y = torch.max(x, torch.tensor(0))  
print(y)

plt.plot(x.numpy(), y.numpy())
plt.title("ReLU Activation")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Leaky Rectified Linear Unit (```LeakyReLU````) is a
# type of activation function used in artificial
# neural networks to introduce non-linearity while
# solving the "dying ReLU" problem.

# %% [markdown]
# It is a variant of the standard Rectified Linear Unit
# (```ReLU```) that, instead of outputting exactly zero
# for all negative inputs, allows a small,
# non-zero gradient, preventing neurons from
# becoming completely inactive during training.
#
# It is defined by the formula:
# $$
# f(x) =
# \begin{cases}
# x, & \text{if } x > 0 \\
# \alpha x, & \text{if } x \le 0
# \end{cases}
# $$

# %%
# Implementing LeakyReLU using torch.where
x = torch.arange(-10, 10)
alpha = 0.02
y = x.where(x >= 0, alpha * x)
y

plt.plot(x.numpy(), y.numpy())
plt.title("Leaky ReLU Activation")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# The ```tanH``` (hyperbolic tangent) function is a mathematical
# function that maps any real-valued input to an output
# between -1 and 1, producing an S-shaped curve (sigmoid)
# centered at zero.

# %% [markdown]
# It is widely used as an activation function in neural
# networks to help with gradient flow and to model
# non-linear relationships, with the formula:

# %% [markdown]
# $$\tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}}$$

# %%
# Implementing tanh manually

x = torch.linspace(-5, 5, 200)

# Implement tanh manually using its mathematical definition
# tanh(x) = (e^x - e^(-x)) / (e^x + e^(-x))
# The output naturally saturates between `-1` and `+1`, 
# which makes `tanh` useful for centering activations around zero.
y = (torch.exp(x) - torch.exp(-x)) / (torch.exp(x) + torch.exp(-x))

# Plot the tanh function
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='tanh(x)', color='teal', linewidth=2)

# Add axis lines and labels
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.title('Tanh Activation Function', fontsize=14)
plt.xlabel('Input', fontsize=12)
plt.ylabel('Output', fontsize=12)
plt.ylim(-1.2, 1.2)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# The ```sigmoid``` function is a mathematical function with a characteristic S-shaped curve ($$\sigma(x) = \frac{1}{1 + e^{-x}}$$) that maps any real-valued number into a range between 0 and 1.
#
# It is widely used in machine learning as an activation function in neural networks and for mapping predicted values to probabilities in logistic regression.

# %%
# Implementing Sigmoid manually

import torch
import matplotlib.pyplot as plt

# Create input tensor
x = torch.linspace(-10, 10, 400)

# Implement sigmoid manually using its mathematical definition
# sigmoid(x) = 1 / (1 + e^(-x))
y = 1 / (1 + torch.exp(-x))

# Plot the sigmoid function
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='sigmoid(x)', color='purple', linewidth=2)
# Add axis lines and labels
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.title('Sigmoid Activation Function', fontsize=14)
plt.xlabel('Input', fontsize=12)
plt.ylabel('Output', fontsize=12)
plt.ylim(-0.1, 1.1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %%
# Comparing Sigmoid / Tanh manually
# Sigmoid and Tanh are both S-shaped activation functions, 
# but they differ in their output ranges and centering.

# Sigmoid functions are used mostly as output activation 
# functions for binary classification problems,
# while Tanh is often used in hidden layers of neural 
# networks to help with centering the activations around zero.

import torch
import matplotlib.pyplot as plt

# Create input tensor
x = torch.linspace(-10, 10, 400)

# Implement sigmoid manually using its mathematical definition
# sigmoid(x) = 1 / (1 + e^(-x))
sigmoid_y = 1 / (1 + torch.exp(-x))

# Implement tanh manually using its mathematical definition
# tanh(x) = (e^x - e^(-x)) / (e^x + e^(-x))
tanh_y = (torch.exp(x) - torch.exp(-x)) / (torch.exp(x) + torch.exp(-x))


# Plot the sigmoid function
plt.figure(figsize=(8, 5))
plt.plot(x, sigmoid_y, label='sigmoid(x)', color='purple', linewidth=2)
plt.plot(x, tanh_y, label='tanh(x)', color='teal', linewidth=2)
# Add axis lines and labels
plt.axhline(0, color='black', linewidth=0.8)
plt.axvline(0, color='black', linewidth=0.8)
plt.title('Sigmoid and Tanh Activation Functions', fontsize=14)
plt.xlabel('Input', fontsize=12)
plt.ylabel('Output', fontsize=12)
plt.ylim(-1.1, 1.1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# The ```softmax``` function is an activation function used in neural networks, primarily for multi-class classification, that converts raw output scores (```logits```) into a probability distribution summing to 1.
#
# It maps each input value to a range between 0 and 1, highlighting the highest value while scaling others, making it ideal for determining the most likely class, especially when paired with Cross Entropy Loss.
#
# $$\sigma(z_i) = \frac{e^{z_i}}{\sum_{j=1}^{n} e^{z_j}}$$

# %%
# Implementing Softmax manually

# Define a wider input range for better visualization
x = torch.linspace(-5, 5, 200)

# Compute softmax for 3 "classes" by shifting x differently
logits = torch.stack([x, x - 2, x + 2])  # simulate 3 different neurons
exp_logits = torch.exp(logits)
softmax_vals = exp_logits / torch.sum(exp_logits, dim=0, keepdim=True)

# Plot softmax probabilities
plt.figure(figsize=(8, 5))

plt.plot(x, softmax_vals[0], label='Class 1', linewidth=2)
plt.plot(x, softmax_vals[1], label='Class 2', linewidth=2)
plt.plot(x, softmax_vals[2], label='Class 3', linewidth=2)

plt.title('Softmax Activation for 3 Classes', fontsize=14)
plt.xlabel('Input (logit value)', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# NOTE: The above activation functions (and many more...) are already implemented in PyTorch under `torch.nn.functional` module.

# %% [markdown]
# ---

# %% [markdown]
# ### Manipulating images using `numpy`

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
img = plt.imread("face.png")

# %%
img.shape

# %%
plt.imshow(img)
plt.show()

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('face.png')
print(img, type(img))
plt.figure(figsize=(10, 5))
plt.imshow(img)
plt.axis('off')  # Hide axis
plt.show()

# %%
img_array = np.array(img)
print(img_array.shape, img_array.size)
img_array

# %%
img2 = img_array[200:400, 500:750, :]

# %%
img2[::2, ::2, :] = 0

# %%
plt.subplot(1, 2, 1)
plt.axis('off')  # Hide axis
plt.imshow(img_array)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.axis('off')  # Hide axis
plt.imshow(img2)
plt.title("Clipped Image")
plt.imsave("face_clipped.png", img2)
plt.show()

# %%
img_array = np.array(img)

y1, x1 = 100, 100  
y2, x2 = 250, 200  
cropped_img = img_array[y1:y2, x1:x2]


plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_array)
plt.title('Original Image')
plt.axis('off')

# Display the cropped image
plt.subplot(1, 2, 2)
plt.imshow(cropped_img)
plt.title('Cropped Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
img = Image.open('face.png')

img_array = np.array(img)


rotated_img = np.rot90(img_array)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_array)
plt.title('Original Image')
plt.axis('off')

# Display the cropped image
plt.subplot(1, 2, 2)
plt.imshow(rotated_img)
plt.title('Rotated Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
a = np.arange(25).reshape(5, 5)
print(a, end="\n\n")
print(np.fliplr(a), end="\n\n")
print(np.flipud(a), end="\n\n")
print(np.rot90(a))

# %%
img = Image.open('face.png')

img_array = np.array(img)


flipped_img = np.fliplr(img_array)


plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_array)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(flipped_img)
plt.title('Flipped Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
img = Image.open('face.png')

img_array = np.array(img)


is_grayscale = len(img_array.shape) < 3

# Function to create negative of an image
def create_negative(image):
    if is_grayscale:
        # For grayscale images
        negative_image = 255 - image
    else:
        # For color images (RGB)
        negative_image = 255 - image
    return negative_image

# Create negative of the image
negative_image = create_negative(img_array)

# negative_image = 255 - img_array

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_array)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(negative_image)
plt.title('Negative Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
img = Image.open('face.png')

# Convert the image to grayscale
# Mode 'L' (Luminance): This mode uses 8-bit pixels, 
# representing black and white with 256 shades of grey.
img_gray = img.convert('L')

# Convert the grayscale image to a NumPy array
img_array = np.array(img_gray)

# Binarize the image using a threshold
threshold = 128
binary_img = np.where(img_array < threshold, 0, 255).astype(np.uint8)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img_array, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(binary_img, cmap='gray')
plt.title('Binary Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# !conda install imageio -y

# %%
img = plt.imread("face.png")

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img[:, :, 0].sum()

# %%
img[:, :, 1].sum()

# %%
img[:, :, 2].sum()

# %%
plt.imshow(img[20:100, 50:150, :])
plt.axis('off')
plt.show()

# %%
img2 = img.copy()
img2[:, :, 2] += 1
plt.imshow(img2)
plt.axis('off')
plt.show()

# %%
plt.imshow(img[::2, :, :])
plt.axis('off')
plt.show()

# %%
img2 = img.copy()
img2[::2, :, :] = 0 
plt.imshow(img2)
plt.axis('off')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Pandas overview

# %% [markdown]
# Pandas a fast, flexible framework that allows data analysis and data manipulation using Python. It allows manipulation of tabular data (spread-sheets) and perform analysis and aid in visualizing the same.

# %% [markdown]
# ##### What Pandas is NOT:
#   - Not a big-data analytics tool
#   - Not Parallel-processing friendly
#
# #### Features
#   - Entire dataset is read into memory
#   - Allows you to run analytics on light-weight / medium-scale data very fast
#
# For Big data analytics: PySpark / Dask

# %% [markdown]
# #### Getting started on Pandas

# %% [markdown]
# To install pandas:
#   - pip install pandas
#
# If you're using Anaconda Python distribution, pandas is pre-bundled in the same

# %%
# !conda install -y pandas

# %%
import pandas as pd

# %%
pd.__version__

# %% [markdown]
# ### Pandas Series and DataFrames

# %% [markdown]
# Pandas **Series** is the rudimentary data-structure in Pandas. It is a labelled one-dimensional array that can hold different types of data (strings, numbers, datetime, or reference to other Python objects).
# A series can be created by the following syntax:
# ```
#    >>> series = pd.Series(data, index=idx)
# ```
#
# The `data` parameter can either be a python list, dictionary or a scalar value.
# The optional `idx` parameter can be a list of numbers/strings for labelling data.

# %%
a = np.array(["Guido", "Raymond", "Alex", "Barry"])
a

# %%
series = pd.Series(["Guido", "Raymond", "Alex", "Barry"])
series

# %%
print(series[0], series[2])

# %%
series = pd.Series([33, 23, 28, 18, 30, 25, 12], 
                   index=["Chennai", "Bengaluru", "Hyderabad", "Pune", "Mumbai", "Delhi", "Noida"])
series

# %%
series["Chennai"]
series["Pune"]

# %%
series.iloc[0]
series.iloc[1]
series.iloc[:3]
series.iloc[-1]

# %%
series.iat[3]

# %% [markdown]
# Accessing series items:
#
# - To access items of a series using index labels, use [] operators directly
# - To access items of a series using list-like indexing, use .iloc[] attribute
# - If you are not intested in "slices" or multi-values and focussed on getting a single item of a series, you can .iat[]

# %%
series

# %%
series = pd.Series(10, index=["temperature"])
series

# %%
scores = pd.Series(10, index=["John", "Barry", "Sam", "Lynne"])
scores

# %%
scores.index

# %%
scores.to_list()

# %%
scores.to_numpy()

# %%
scores.index.to_numpy()

# %%
torch.from_numpy(scores.to_numpy().copy())

# %%
torch.tensor(scores.to_list())

# %%
print(scores.to_csv())

# %%
ct = pd.Series([33, 23, 28, 18, 30, 25, 12], 
                   index=["Chennai", "Bengaluru", "Hyderabad", "Pune", "Mumbai", "Delhi", "Noida"])
ct

# %%
ct += 10
ct

# %%
ct.sum(), ct.min(), ct.max(), ct.mean()

# %%
ct.iloc[1:5]

# %%
ct["Bengaluru" : "Mumbai"]

# %%
ct = pd.Series([33, 23, 28, 18, 30, 25, 12], 
                   index=["Chennai", "Pune", "Hyderabad", "Pune", "Mumbai", "Delhi", "Noida"])
ct

# %%
ct["Pune"]

# %%
s = pd.Series(["John", "Smith", "Adrian", "Jones", "Lynne", "Claire"], index=[0, 2, 1, 2, 5, 7], name="users")
s

# %%
s[1]

# %%
s.iloc[1], s.iat[1]

# %%
s[2]

# %%
s.name

# %%
s.iat[1]

# %%
s.loc[1]

# %%
s = pd.Series([11, 22, 33, 4, 55, 6])
s.notna()

# %%
ct = pd.Series({"Chennai": 34, "Delhi": 38, "Pune": 30, "Bengaluru": 25})
ct

# %%
# For array-like data, the size of index must match the size of the data
pd.Series(["john", "sam", "smith"], index=[1, 2, 3])

# %%
city_idx = ["Delhi", "Kolkatta", "Pune", "Mumbai", "Bengaluru", "Chennai"]

data  = {"Chennai": 34, "Delhi": 38, "Pune": 30, "Bengaluru": 25, "Hyderabad": 33}

ct = pd.Series(data, index=city_idx)
ct

# %%
city_idx = ["Delhi", "Kolkatta", "Pune", "Mumbai", "Bengaluru", "Chennai"]

data  = {"Chennai": 34, "Delhi": 38, "Pune": 30, "Bengaluru": 25, "Hyderabad": 33}

ct = pd.Series(data, index=city_idx).dropna()
ct

# %%
ct.notna()

# %%
ct.isna().any()

# %%
ct

# %%
ct.dropna()

# %%
ct

# %%
weather = pd.Series([23, 25, 24, 26, 28, np.nan, 25, 22])
weather

# %%
weather = pd.Series([23, 25, 24, np.nan, np.nan, np.nan, 25, 22])
#weather.interpolate(method="pad")
weather.ffill()

# %%
weather.dropna(inplace=True)

# %%
weather

# %%
weather.interpolate?

# %%
weather = pd.Series([23, 25, 24, np.nan, np.nan, np.nan, 25, 22])
weather.prod()

# %%
weather = pd.Series([23, 25, 24, np.nan, np.nan, np.nan, 25, 22])
weather.fillna(10)

# %%
weather = pd.Series([23, 25, 24, np.nan, np.nan, np.nan, 25, 22])
weather.fillna({3: 12, 5: 15, 4: 10, 1: 55})

# %%
weather.index = ["Delhi", "Chennai", "Kolkatta", "Bengaluru", "Pune", "Hyderabad", "Noida", "Nagpur"]
weather

# %%
weather = pd.Series([23, 25, 24, np.nan, np.nan, np.nan, 25, 22])
weather

# %%
weather.rename({4: 10})

# %%
weather = pd.Series([23, 25, 24, np.nan, np.nan, np.nan, 25, 22])

# %% [markdown]
# ### Pandas DataFrame

# %% [markdown]
# In Pandas, a **DataFrame** is a 2-dimensional labeled data structure with columns of potentially different types. It is a representation of a row-column table similar to an excel spreadsheet. It is the most commonly used pandas object.
#
# Technically, a **DataFrame** is a collection of **Series**

# %% [markdown]
# #### Loading DataFrame from various data sources

# %% [markdown]
# Pandas allows loading DataFrame from various data sources, that include:
#   - Excel spreadsheets (xls, xlsx, ...)
#   - CSV files
#   - JSON streams
#   - HTML Tables
#   - SQL compliant database tables
#   - Python pickled data-source representing records of structured data
#   - Python dictionaries and 2-D lists/tuples
#   - Numpy arrays which are 2-D form.

# %%
df = pd.read_csv("weather_data.csv")
df

# %%
df["day"]

# %%
df.iloc[0]

# %%
df.loc[0]

# %%
df["event"]

# %%
df.iloc[3]

# %%
df[["day", "event"]]

# %%
df["event"]

# %%
df[["event"]]

# %%
df.temperature # Convenient equivalent of df["temperature"]

# %%
df

# %%
df[["temperature", "event"]]  # If index is passed as a list, result will always be a dataframe object

# %%
df[df.event == "Sunny"]["day"]

# %%
# %%timeit
df[(df.event == "Sunny") & (df.temperature > 33)]

# %%
# %%timeit
r = df[df.event == "Sunny"]
r[r.temperature > 33]

# %%
df[df.event == "Sunny"][["day"]]

# %% [markdown]
# ### Reading large CSV documents using chunked reading

# %%
tf = pd.read_csv("delhi_weather.csv", chunksize=100)
tf

# %%
df = next(tf)
df

# %%
pd.read_csv?

# %%
df = pd.read_excel("stocks.xlsx")
df

# %%
df.to_csv("stocks_data.csv")

# %%
simple_data = {
    "names": ["alex", "guido", "raymod", "david"],
    "places": ["seattle", "san francisco", "new york", "chicago"]
}

pd.DataFrame(simple_data)

# %%
simple_data = [
    {"name": "alex", "place": "seattle"},
    {"name": "guido", "place": "san francisco", "age": 40},
]
pd.DataFrame(simple_data)

# simple_data can also be any iterable (for instance - a generator) that 
# provide a dictionary as record when you iterate over it.

# %%
days = pd.date_range("2020-03-01", "2020-03-31")
temperatures = np.random.randint(20, 34, size=31)
windspeed = np.random.randint(3, 15, size=31)

# %%
import random
events = random.sample(["Sunny", "Cloudy", "Light Shower", "Rain"]*10, 31)

# %%
print(days, temperatures, windspeed, events)

# %%
weather_data = {
    'day': days, 
    'temperature': temperatures,
    'windspeed': windspeed,
    'events': events
}

# %%
df = pd.DataFrame(weather_data)
df.tail(1)

# %%
df.shape # rows, columns = df.shape

# %% [markdown]
# ### Indexing and Selecting data

# %% [markdown]
# #### Accessing rows of a DataFrame

# %%
df.head()

# %%
df.head(3)

# %%
df.tail()

# %%
df.tail(3)

# %%
df[5:10]

# %%
df.iloc[5:10]

# %%
df.loc[3]

# %%
df

# %% [markdown]
# ### Managing indices

# %%
df.set_index("day", inplace=True)

# %%
df

# %%
df[1:5]

# %%
df.iloc[1]

# %%
df.iloc[1:5]

# %%
df.loc["2020-03-04"]

# %%
df.loc["2020-03-10", "events"]

# %%
df.loc["2020-03-10":"2020-03-15"]

# %%
df.loc["2020-03-10":"2020-03-15", "events"]

# %%
df.loc["2020-03-10":"2020-03-15", ["temperature", "windspeed"]]

# %%
df.event

# %%
df[["day", "temperature"]]

# %%
df.set_index("day", inplace=True)

# %%
df.head()

# %%
df.loc["2020-02-03"]

# %%
df.iloc[2]

# %%
df

# %%
df.reset_index(inplace=True)
df.head()

# %%
df[3:4]

# %%
df.loc[3]

# %%
df.iloc[3]

# %%
df.set_index("day", inplace=True)

# %%
df.head()

# %%
df.loc[3]

# %%
df.loc["2020-03-04"]

# %%
df.iloc[3]

# %%
df.loc[pd.date_range("2020-03-10", "2020-03-15")]

# %% [markdown]
# #### Exercise (Homework):
# Web server access_log file is available via https://files.chandrashekar.info/access_log
#
# Read a web-server access_log file, convert to CSV and use pandas to perform the following analytics:
#
# Format_needed = '{client_ipaddr} - - [{timestamp}] "{request_method} {request_url} HTTP/1.0" {response_code} {response_bytes} "{referer_url}" "{user_agent}" ...'
#
#
# log_format = '51.15.43.205 - - [01/Jan/2017:00:01:14 -0500] "GET /random-thoughts/godmen-leaders-and-superstars.html HTTP/1.0" 200 44545 "-" "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.109 Safari/537.36" 0 0 "off:-:-" 365 855116 192.252.149.39 chandrashekar.info'
#
#
# record = {
#     "client_ipaddr": "51.15.43.205",
#     "timestamp": "01/Jan/2017:00:01:14 -0500"
#     "request_method": "GET",
#     "request_url": "/random-thoughts/godmen-leaders-and-superstars.html",
#     "response_code": "200",
#     "transferred_bytes": "44545",
#     "referer_url": "-",
#     "user_agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.109 Safari/537.36"
# }
#
# ----------------------------------------------------
#
# A. Find out the following high-level statistics:
#    1. Which client has the maximum hit on my website
#    2. Total traffic generation on my website
#    3. Top 10 referers to my website
#
# B. Find out the following detailed statistics:
#    1. Top 5 request_url was the mosted accessed with referer_url being set
#    2. Top 10 request_urls and client_ips for response code that is not 200
#    3. Top 10 client that generated the most traffic
